# %% [markdown]
# # DATA Visualization using Matplotlib
#
# Data Visualization is an important part of business activities as organizations nowadays
# collect a huge amount of data. Sensors all over the world are collecting climate data, user data
# through clicks, car data for prediction of steering wheels etc. All of these data collected
# hold key insights for businesses and visualizations make these insights easy to interpret.
# Visualizations are the easiest way to analyze and absorb information. Visuals help to easily
# understand the complex problem. They help in identifying patterns, relationships, and outliers in data.
# It helps in understanding business problems better and quickly. It helps to build a compelling story based on visuals.
# Insights gathered from the visuals help in building strategies for businesses. It is also a precursor to many high-level
# data analysis for Exploratory Data Analysis(EDA) and Machine Learning(ML).
# Data visualizations in python can be done via many packages. We’ll be discussing of matplotlib package.
# It can be used in Python scripts, Jupyter notebook, and web application servers.
#
# Matplotlib is a 2-D plotting library that helps in visualizing figures.
# Matplotlib emulates Matlab like graphs and visualizations. Matlab is not free, is difficult to scale
# and as a programming language is tedious. So, matplotlib in Python is used
# as it is a robust, free and easy library for data visualization.
#
#
# Importing required libraries and dataset to plot using Pandas pd.read_csv()
#
# Extracting important parts using conditions on Pandas Dataframes.
#
# plt.plot() for plotting line chart simililarly in place of plot other functions are used for plotting.
#          All plotting functions require data and it is provided in the function
#          through parameters ,plot.xlable,plt.ylabel for labelling x and y axis respectively.

# %%
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np

# %%
a=np.array([1,2,3,4,5,6,7])
b=np.array([1,2,3,4,5,6,7])

# %%
plt.title("Linear Line")
plt.xlabel("a")
plt.ylabel("b")
plt.plot(a,b)
plt.show()

# %%
p=np.array([11,21,30,47,55,68,70])
q=np.array([1,2,3,4,5,6,7])

# %%
plt.title("Linear Line")
plt.xlabel("p")
plt.ylabel("q")
plt.plot(p,q)
plt.show()

# %%
g=np.array([44,56,99,86,12,56,80,10])
h=np.array([9,8,7,6,5,4,3,2])
plt.xlabel("g")
plt.ylabel("h")
plt.plot(g,h)
plt.show()

# %%
plt.plot(g,h,'--g')
plt.show()

# %%
X = [5,8,10,2,6,12]
Y = [12,16,6,10,14,6]
plt.bar(X,Y)
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.plot(X,Y)
plt.show()

# %%
X = [5,8,10,2,6,12]
Y = [12,16,6,10,14,6]
plt.bar(X,Y)
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
plt.bar(X,Y, color = 'g', align = 'center')
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %% [markdown]
# # HISTOGRAM

# %% [markdown]
# A histogram takes in a series of data and divides the data into a number of bins.
# It then plots the frequency data points in each bin (i.e. the interval of points).
# It is useful in understanding the count of data ranges.
# When to use: We should use histogram when we need the count of the variable in a plot.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a, bins = [0,20,40,60,80,100])
plt.title("histogram")
plt.show()

# %%
# https://github.com/dsrscientist/dataset1/blob/b6976f2fc1bf387a4097b570d56e9549ea5dec9f/student_marks.csv

import pandas as pd
df=pd.read_csv('student_marks.csv')
print(df)
df.columns
# Out:
#          Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# John          M  05-04-1988     55       45         56       87       21
# Suresh        M  04-05-1987     75       96         78       64       90
# Ramesh        M  25-05-1989     25       54         89       76       95
# Jessica       F  12-08-1990     78       96         86       63       54
# Jennifer      F  02-09-1989     58       96         78       46       96
# Annu          F  05-04-1988     45       87         52       89       55
# pooja         F  04-05-1987     55       64         61       58       75
# Ritesh        M  25-05-1989     54       76         87       56       25
# Farha         F  12-08-1990     55       63         89       75       78
# Mukesh        M  02-09-1989     96       46         77       83       58
#
#           Economics  History  Civics
# John             52       89      65
# Suresh           61       58       2
# Ramesh           87       56      74
# ...

# %%
plt.hist(df['Maths'],bins=10)
plt.title("Maths Histogram")
plt.show()

# %%
plt.hist(df['English'],bins=10)
plt.title("English")
plt.show()

# %%
plt.hist(df['Physics'],bins=10)
plt.title("Physics")
plt.show()

# %%
plt.hist(df['Chemistry'],bins=10)
plt.title("Chemistry")
plt.show()

# %%
#Boxplot
plt.boxplot(df["Maths"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1628f43daf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1628f44e0d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1628f43d880>],
#  'medians': [<matplotlib.lines.Line2D at 0x1628f44e670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1628f44e940>],
#  'means': []}

# %%
plt.boxplot(df['Chemistry'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1628f4b0370>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1628f4b0910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1628f4b00a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1628f4b0eb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1628f4be1c0>],
#  'means': []}

# %%
plt.violinplot(df['Maths'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1628f50b9d0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1628f50b940>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1628f529100>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1628f5294c0>}

# %%
plt.violinplot(df['Chemistry'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1628f58a700>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1628f58a670>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1628f58adc0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1628f59a1c0>}

# %%
plt.violinplot(df['Physics'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1628f5f8a60>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1628f5f89d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1628f605100>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1628f6054c0>}

# %%
x=np.array([3,6,55,7,89,55,21,45])
y=np.array([22,4,5,78,8,42,22,11])
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(x,y)
plt.show()

# %%
a = np.array([44,56,99,86,12,56,80,10,66,87,4,1,20,7,99])
b = np.array([9,8,7,6,5,4,3,2,5,22,9,10,11,13,15])
plt.title("scatter plot")
plt.xlabel('a')
plt.ylabel('b')
plt.scatter(a,b)
plt.show()

# %%
x=df["Maths"]
y=df["English"]

# %%
plt.scatter(x,y)
plt.xlabel("Maths")
plt.ylabel("English")
plt.show()

# %% [markdown]
# # Matlibplot over
